# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # Task 1

# %% [markdown]
# Task 1.1: Importing covid19 dataset

# %%
corona_csv = pd.read_csv('Covid19_Confirmed_dataset.csv')
corona_csv.head()

# observation:- data is from 22 January 2020 to 30 April 2020
# Out:
#   Province/State Country/Region      Lat     Long  1/22/20  1/23/20  1/24/20  \
# 0            NaN    Afghanistan  33.0000  65.0000        0        0        0
# 1            NaN        Albania  41.1533  20.1683        0        0        0
# 2            NaN        Algeria  28.0339   1.6596        0        0        0
# 3            NaN        Andorra  42.5063   1.5218        0        0        0
# 4            NaN         Angola -11.2027  17.8739        0        0        0
#
#    1/25/20  1/26/20  1/27/20  ...  4/21/20  4/22/20  4/23/20  4/24/20  \
# 0        0        0        0  ...     1092     1176     1279     1351
# 1        0        0        0  ...      609      634      663      678
# 2        0        0        0  ...     2811     2910     3007     3127
# 3        0        0        0  ...      717      723      723      731
# 4        0        0        0  ...       24       25       25       25
#
#    4/25/20  4/26/20  4/27/20  4/28/20  4/29/20  4/30/20
# ...

# %%
column = corona_csv.columns
columns=[column for column in corona_csv.columns]
print(columns)
# Out:
# ['Province/State', 'Country/Region', 'Lat', 'Long', '1/22/20', '1/23/20', '1/24/20', '1/25/20', '1/26/20', '1/27/20', '1/28/20', '1/29/20', '1/30/20', '1/31/20', '2/1/20', '2/2/20', '2/3/20', '2/4/20', '2/5/20', '2/6/20', '2/7/20', '2/8/20', '2/9/20', '2/10/20', '2/11/20', '2/12/20', '2/13/20', '2/14/20', '2/15/20', '2/16/20', '2/17/20', '2/18/20', '2/19/20', '2/20/20', '2/21/20', '2/22/20', '2/23/20', '2/24/20', '2/25/20', '2/26/20', '2/27/20', '2/28/20', '2/29/20', '3/1/20', '3/2/20', '3/3/20', '3/4/20', '3/5/20', '3/6/20', '3/7/20', '3/8/20', '3/9/20', '3/10/20', '3/11/20', '3/12/20', '3/13/20', '3/14/20', '3/15/20', '3/16/20', '3/17/20', '3/18/20', '3/19/20', '3/20/20', '3/21/20', '3/22/20', '3/23/20', '3/24/20', '3/25/20', '3/26/20', '3/27/20', '3/28/20', '3/29/20', '3/30/20', '3/31/20', '4/1/20', '4/2/20', '4/3/20', '4/4/20', '4/5/20', '4/6/20', '4/7/20', '4/8/20', '4/9/20', '4/10/20', '4/11/20', '4/12/20', '4/13/20', '4/14/20', '4/15/20', '4/16/20', '4/17/20', '4/18/20', '4/19
# ...

# %%
print(len(columns))
# Out:
# 104

# %% [markdown]
# # Task 2- Data Cleaning

# %% [markdown]
# Dropping unnecessary columns

# %%
corona_csv.drop(['Lat'], axis=1 , inplace=True)
corona_csv.head()
# Out:
#   Province/State Country/Region     Long  1/22/20  1/23/20  1/24/20  1/25/20  \
# 0            NaN    Afghanistan  65.0000        0        0        0        0
# 1            NaN        Albania  20.1683        0        0        0        0
# 2            NaN        Algeria   1.6596        0        0        0        0
# 3            NaN        Andorra   1.5218        0        0        0        0
# 4            NaN         Angola  17.8739        0        0        0        0
#
#    1/26/20  1/27/20  1/28/20  ...  4/21/20  4/22/20  4/23/20  4/24/20  \
# 0        0        0        0  ...     1092     1176     1279     1351
# 1        0        0        0  ...      609      634      663      678
# 2        0        0        0  ...     2811     2910     3007     3127
# 3        0        0        0  ...      717      723      723      731
# 4        0        0        0  ...       24       25       25       25
#
#    4/25/20  4/26/20  4/27/20  4/28/20  4/29/20  4/30/20
# ...

# %%
corona_csv.drop(['Long'] , axis=1 , inplace=True)
corona_csv.head()
# Out:
#   Province/State Country/Region  1/22/20  1/23/20  1/24/20  1/25/20  1/26/20  \
# 0            NaN    Afghanistan        0        0        0        0        0
# 1            NaN        Albania        0        0        0        0        0
# 2            NaN        Algeria        0        0        0        0        0
# 3            NaN        Andorra        0        0        0        0        0
# 4            NaN         Angola        0        0        0        0        0
#
#    1/27/20  1/28/20  1/29/20  ...  4/21/20  4/22/20  4/23/20  4/24/20  \
# 0        0        0        0  ...     1092     1176     1279     1351
# 1        0        0        0  ...      609      634      663      678
# 2        0        0        0  ...     2811     2910     3007     3127
# 3        0        0        0  ...      717      723      723      731
# 4        0        0        0  ...       24       25       25       25
#
#    4/25/20  4/26/20  4/27/20  4/28/20  4/29/20  4/30/20
# ...

# %%
corona_csv = corona_csv.rename(columns={'Province/State': 'state', 'Country/Region': 'country'})
corona_csv.head()
# Out:
#   state      country  1/22/20  1/23/20  1/24/20  1/25/20  1/26/20  1/27/20  \
# 0   NaN  Afghanistan        0        0        0        0        0        0
# 1   NaN      Albania        0        0        0        0        0        0
# 2   NaN      Algeria        0        0        0        0        0        0
# 3   NaN      Andorra        0        0        0        0        0        0
# 4   NaN       Angola        0        0        0        0        0        0
#
#    1/28/20  1/29/20  ...  4/21/20  4/22/20  4/23/20  4/24/20  4/25/20  \
# 0        0        0  ...     1092     1176     1279     1351     1463
# 1        0        0  ...      609      634      663      678      712
# 2        0        0  ...     2811     2910     3007     3127     3256
# 3        0        0  ...      717      723      723      731      738
# 4        0        0  ...       24       25       25       25       25
#
#    4/26/20  4/27/20  4/28/20  4/29/20  4/30/20
# ...

# %%
corona_csv_agg = corona_csv.groupby("country").sum()

# %%
corona_csv_agg
# Out:
#                     1/22/20  1/23/20  1/24/20  1/25/20  1/26/20  1/27/20  \
# country
# Afghanistan               0        0        0        0        0        0
# Albania                   0        0        0        0        0        0
# Algeria                   0        0        0        0        0        0
# Andorra                   0        0        0        0        0        0
# Angola                    0        0        0        0        0        0
# ...                     ...      ...      ...      ...      ...      ...
# West Bank and Gaza        0        0        0        0        0        0
# Western Sahara            0        0        0        0        0        0
# Yemen                     0        0        0        0        0        0
# Zambia                    0        0        0        0        0        0
# Zimbabwe                  0        0        0        0        0        0
#
#                     1/28/20  1/29/20  1/30/20  1/31/20  ...  4/21/20  4/22/20  \
# ...

# %%
#we have 187 countries, 100 dates

# %% [markdown]
# # Task 3:-Visualizing data related to a country for example China

# %%
result=corona_csv_agg.loc["China"]
result
# Out:
# 1/22/20      548
# 1/23/20      643
# 1/24/20      920
# 1/25/20     1406
# 1/26/20     2075
#            ...
# 4/26/20    83912
# 4/27/20    83918
# 4/28/20    83940
# 4/29/20    83944
# 4/30/20    83956
# Name: China, Length: 100, dtype: int64

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
corona_csv_agg.loc["China"].plot()
plt.xlabel("Dates")
plt.ylabel("Corona Cases")
plt.legend()
plt.show()

# %%
corona_csv_agg.loc["Egypt"].plot()
plt.xlabel("Dates")
plt.ylabel("Corona Cases")
plt.legend()
plt.show()

# %%
corona_csv_agg.loc['China'].plot()
corona_csv_agg.loc['Italy'].plot()
corona_csv_agg.loc['Spain'].plot()
plt.xlabel("Dates")
plt.ylabel("Corona Cases")
plt.legend()
plt.show()

# %%
#Spike in 
corona_csv_agg.loc['China'][:3].plot()  
plt.xlabel("Dates")
plt.ylabel("Corona Cases")
plt.legend()
plt.show()

# %% [markdown]
# In the 1st 24 hrs, an increase in case (550 to 650) by 100
#
# In the 2nd 24 hrs, an increase (650 to 900) by 250

# %%
corona_csv_agg.loc["China"].diff().plot()
plt.xlabel("Dates")
plt.ylabel("Corona Cases")
plt.legend()
plt.show()

# %%
corona_csv_agg.loc["China"].diff().max()
# Out:
# 15136.0

# %% [markdown]
# # Task 4: find maximum infection rate for all of the countries.

# %%
countries = corona_csv_agg.loc[a].diff()
countries
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [49], in <cell line: 1>()
# ----> 1 countries = corona_csv_agg.loc[a].diff()
#       2 countries
#
# NameError: name 'a' is not defined

# %%
countries = list(corona_csv_agg.index)
max_infection_rates = []
for c in countries :
    max_infection_rates.append(corona_csv_agg.loc[c].diff().max())
max_infection_rates
# Out:
# [232.0,
#  34.0,
#  199.0,
#  43.0,
#  5.0,
#  6.0,
#  291.0,
#  134.0,
#  497.0,
#  1321.0,
#  105.0,
#  7.0,
#  301.0,
#  641.0,
#  12.0,
#  1485.0,
#  2454.0,
#  4.0,
#  19.0,
#  1.0,
#  104.0,
#  92.0,
#  7.0,
#  7502.0,
#  26.0,
#  137.0,
#  41.0,
#  21.0,
#  6.0,
#  45.0,
#  31.0,
#  203.0,
#  2778.0,
#  31.0,
#  21.0,
#  1138.0,
#  15136.0,
#  353.0,
#  1.0,
#  57.0,
#  81.0,
#  37.0,
#  113.0,
#  96.0,
#  63.0,
#  58.0,
#  381.0,
#  391.0,
#  99.0,
#  156.0,
#  5.0,
#  371.0,
#  11536.0,
#  269.0,
#  32.0,
#  130.0,
#  7.0,
#  134.0,
#  20.0,
#  9.0,
#  5.0,
#  267.0,
#  26849.0,
#  38.0,
#  5.0,
#  42.0,
#  6933.0,
#  403.0,
#  156.0,
#  6.0,
#  68.0,
#  167.0,
#  132.0,
#  12.0,
#  10.0,
#  3.0,
#  72.0,
#  210.0,
#  99.0,
#  1893.0,
#  436.0,
#  3186.0,
#  91.0,
#  1515.0,
#  1131.0,
#  6557.0,
#  52.0,
#  1161.0,
#  40.0,
#  264.0,
#  29.0,
#  851.0,
#  289.0,
#  300.0,
#  69.0,
#  3.0,
#  48.0,
#  61.0,
#  17.0,
#  13.0,
#  21.0,
#  90.0,
#  234.0,
#  7.0,
#  14.0,
# ...

# %%
print(len(max_infection_rates))
# Out:
# 187

# %%
corona_csv_agg["max_infection_rates"] = max_infection_rates

# %%
corona_csv_agg.head()
# Out:
#              1/22/20  1/23/20  1/24/20  1/25/20  1/26/20  1/27/20  1/28/20  \
# country
# Afghanistan        0        0        0        0        0        0        0
# Albania            0        0        0        0        0        0        0
# Algeria            0        0        0        0        0        0        0
# Andorra            0        0        0        0        0        0        0
# Angola             0        0        0        0        0        0        0
#
#              1/29/20  1/30/20  1/31/20  ...  4/22/20  4/23/20  4/24/20  \
# country                                 ...
# Afghanistan        0        0        0  ...     1176     1279     1351
# Albania            0        0        0  ...      634      663      678
# Algeria            0        0        0  ...     2910     3007     3127
# Andorra            0        0        0  ...      723      723      731
# Angola             0        0        0  ...       25       25       25
#
# ...

# %% [markdown]
# # Task 5: create a new dataframe with only needed column

# %%
corona_data = pd.DataFrame(corona_csv_agg["max_infection_rates"])
corona_data.head()
# Out:
#              max_infection_rates
# country
# Afghanistan                232.0
# Albania                     34.0
# Algeria                    199.0
# Andorra                     43.0
# Angola                       5.0

# %% [markdown]
# # Task6:

# %% [markdown]
# Importing the WorldHappinessReport.csv dataset
#
# selecting needed columns for our analysis
#
# join the datasets
#
# calculate the correlations as the result of our analysis

# %%
#importing the dataset
happiness_report_csv = pd.read_csv("worldwide_happiness_report.csv")
happiness_report_csv.head()
# Out:
#    Overall rank Country or region  Score  GDP per capita  Social support  \
# 0             1           Finland  7.769           1.340           1.587
# 1             2           Denmark  7.600           1.383           1.573
# 2             3            Norway  7.554           1.488           1.582
# 3             4           Iceland  7.494           1.380           1.624
# 4             5       Netherlands  7.488           1.396           1.522
#
#    Healthy life expectancy  Freedom to make life choices  Generosity  \
# 0                    0.986                         0.596       0.153
# 1                    0.996                         0.592       0.252
# 2                    1.028                         0.603       0.271
# 3                    1.026                         0.591       0.354
# 4                    0.999                         0.557       0.322
#
#    Perceptions of corruption
# 0                      0.393
# 1                      0.410
# ...

# %%
#let's drop the useless columns

# %%
useless_cols = ["Overall rank", "Score", "Generosity", "Perceptions of corruption"]
happiness_report_csv.drop(useless_cols, axis=1, inplace=True)
happiness_report_csv.head()
# Out:
#   Country or region  GDP per capita  Social support  Healthy life expectancy  \
# 0           Finland           1.340           1.587                    0.986
# 1           Denmark           1.383           1.573                    0.996
# 2            Norway           1.488           1.582                    1.028
# 3           Iceland           1.380           1.624                    1.026
# 4       Netherlands           1.396           1.522                    0.999
#
#    Freedom to make life choices
# 0                         0.596
# 1                         0.592
# 2                         0.603
# 3                         0.591
# 4                         0.557

# %%
happiness_report_csv = happiness_report_csv.rename(columns={'Country or region': 'country', 'Freedom to make life choices': 'freedom'})
happiness_report_csv.head()
# Out:
#        country  GDP per capita  Social support  Healthy life expectancy  \
# 0      Finland           1.340           1.587                    0.986
# 1      Denmark           1.383           1.573                    0.996
# 2       Norway           1.488           1.582                    1.028
# 3      Iceland           1.380           1.624                    1.026
# 4  Netherlands           1.396           1.522                    0.999
#
#    freedom
# 0    0.596
# 1    0.592
# 2    0.603
# 3    0.591
# 4    0.557

# %%
happiness_report_csv.set_index("country", inplace=True)

# %%
happiness_report_csv.head()
# Out:
#              GDP per capita  Social support  Healthy life expectancy  freedom
# country
# Finland               1.340           1.587                    0.986    0.596
# Denmark               1.383           1.573                    0.996    0.592
# Norway                1.488           1.582                    1.028    0.603
# Iceland               1.380           1.624                    1.026    0.591
# Netherlands           1.396           1.522                    0.999    0.557

# %%
##now let's join two dataset we have prepared

# %%
corona_data.head()
# Out:
#              max_infection_rates
# country
# Afghanistan                232.0
# Albania                     34.0
# Algeria                    199.0
# Andorra                     43.0
# Angola                       5.0

# %%
happiness_report_csv.head()
# Out:
#              GDP per capita  Social support  Healthy life expectancy  freedom
# country
# Finland               1.340           1.587                    0.986    0.596
# Denmark               1.383           1.573                    0.996    0.592
# Norway                1.488           1.582                    1.028    0.603
# Iceland               1.380           1.624                    1.026    0.591
# Netherlands           1.396           1.522                    0.999    0.557

# %%
data = corona_data.join(happiness_report_csv, how = "inner")
data.head()
# Out:
#              max_infection_rates  GDP per capita  Social support  \
# country
# Afghanistan                232.0           0.350           0.517
# Albania                     34.0           0.947           0.848
# Algeria                    199.0           1.002           1.160
# Argentina                  291.0           1.092           1.432
# Armenia                    134.0           0.850           1.055
#
#              Healthy life expectancy  freedom
# country
# Afghanistan                    0.361    0.000
# Albania                        0.874    0.383
# Algeria                        0.785    0.086
# Argentina                      0.881    0.471
# Armenia                        0.815    0.283

# %%
##correlation matrix

# %%
data.corr()
# Out:
#                          max_infection_rates  GDP per capita  Social support  \
# max_infection_rates                 1.000000        0.250118        0.191958
# GDP per capita                      0.250118        1.000000        0.759468
# Social support                      0.191958        0.759468        1.000000
# Healthy life expectancy             0.289263        0.863062        0.765286
# freedom                             0.078196        0.394603        0.456246
#
#                          Healthy life expectancy   freedom
# max_infection_rates                     0.289263  0.078196
# GDP per capita                          0.863062  0.394603
# Social support                          0.765286  0.456246
# Healthy life expectancy                 1.000000  0.427892
# freedom                                 0.427892  1.000000

# %% [markdown]
# +ve correlation between max_infection-rate and all other feature

# %% [markdown]
# # Task 5: Visualization of the results

# %%
data.head()
# Out:
#              max_infection_rates  GDP per capita  Social support  \
# country
# Afghanistan                232.0           0.350           0.517
# Albania                     34.0           0.947           0.848
# Algeria                    199.0           1.002           1.160
# Argentina                  291.0           1.092           1.432
# Armenia                    134.0           0.850           1.055
#
#              Healthy life expectancy  freedom
# country
# Afghanistan                    0.361    0.000
# Albania                        0.874    0.383
# Algeria                        0.785    0.086
# Argentina                      0.881    0.471
# Armenia                        0.815    0.283

# %% [markdown]
# # Plotting GDP per capita vs maximum Infection rate

# %%
x = data["GDP per capita"]
y = data["max_infection_rates"]
sns.scatterplot(x=x,y=y)
plt.show()

# %% [markdown]
# We can see the values need different scaling

# %%
#Will apply log scaling to y
x = data["GDP per capita"]
y = data["max_infection_rates"]
sns.scatterplot(x=x,y=np.log(y))
plt.show()

# %% [markdown]
# Now we can see +ve correlation

# %%
#RegPlot
x = data["GDP per capita"]
y = data["max_infection_rates"]

sns.regplot(x=x,y=np.log(y))
plt.show()

# %% [markdown]
# Line fitted, +ve slope seen

# %% [markdown]
# # Plotting Healthy life expectancy vs maximum Infection rate

# %%
x = data["Healthy life expectancy"]
y = data["max_infection_rates"]

sns.scatterplot(x=x,y=np.log(y))
plt.show()

# %%
x = data["Healthy life expectancy"]
y = data["max_infection_rates"]

sns.regplot(x=x,y=np.log(y))
plt.show()

# %% [markdown]
# # Plotting freedom vs maximum Infection rate

# %%
x = data["freedom"]
y = data["max_infection_rates"]

sns.scatterplot(x=x,y=np.log(y))
plt.show()

# %%
x = data["freedom"]
y = data["max_infection_rates"]

sns.regplot(x=x,y=np.log(y))
plt.show()

# %% [markdown]
# # Plotting Social support vs maximum Infection rate

# %%
x = data["Social support"]
y = data["max_infection_rates"]

sns.scatterplot(x=x,y=np.log(y))
plt.show()

# %%
x = data["Social support"]
y = data["max_infection_rates"]

sns.regplot(x=x,y=np.log(y))
plt.show()
